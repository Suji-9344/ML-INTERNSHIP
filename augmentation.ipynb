# %%
import os
os.makedirs("images", exist_ok=True)
print("Now upload images into the 'images' folder shown on the left panel.")
# Out:
# Now upload images into the 'images' folder shown on the left panel.

# %%
# !pip install Augmentor

# %%
import Augmentor

p = Augmentor.Pipeline("/content/drive/MyDrive/archive (1)/cat folder/drive-download-20251211T054803Z-1-001")     # Your image folder
p.flip_left_right(probability=1)     # Flip
p.rotate(probability=1, max_left_rotation=15, max_right_rotation=15)   # Rotate

p.sample(40)   # Generate 20 augmented images
# Out:
# Initialised with 5 image(s) found.
# Output directory set to /content/drive/MyDrive/archive (1)/cat folder/drive-download-20251211T054803Z-1-001/output.
# Processing <PIL.Image.Image image mode=RGB size=224x224 at 0x79901F864C80>: 100%|██████████| 40/40 [00:00<00:00, 80.37 Samples/s]
